# %% [markdown]
# ## This notebook is made to calculate the correlation between OMV AG share price and Brent Crude and shows their cumulative returns between January 2016 and August 2020.

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

# Importing the dataset
def __iter__(self): return 0

# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#    Month  Year  OMV AG – VIE  Brent Crude
# 0      8  2020         27.26        45.28
# 1      8  2020         27.58        45.81
# 2      8  2020         27.54        45.60
# 3      8  2020         28.10        45.64
# 4      8  2020         28.00        45.86

# %%
df = df_data_1
df.head()
# Out:
#    Month  Year  OMV AG – VIE  Brent Crude
# 0      8  2020         27.26        45.28
# 1      8  2020         27.58        45.81
# 2      8  2020         27.54        45.60
# 3      8  2020         28.10        45.64
# 4      8  2020         28.00        45.86

# %%
# calculating the Pearson's correlation between OMV AG and Brent Crude
from scipy.stats import pearsonr
# preparing data
data1 = df["OMV AG – VIE"]
data2 = df["Brent Crude"]
# calculating Pearson's correlation
corr, _ = pearsonr(data1, data2)
print('OMV AG and Brent Crude has a positive correlation of: %.3f' % corr)
# Out:
# OMV AG and Brent Crude has a positive correlation of: 0.785

# %%
# Coverting the dataset for plotting
df1 = df.groupby(["Year", "Month"]).mean()

# %%
df.dtypes
# Out:
# Month             int64
# Year              int64
# OMV AG – VIE    float64
# Brent Crude     float64
# dtype: object

# %%
df1.head()
# Out:
#             OMV AG – VIE  Brent Crude
# Year Month
# 2016 1         23.216842    31.830526
#      2         23.365476    33.631905
#      3         25.122143    39.795714
#      4         25.131905    43.289524
#      5         25.427105    47.684211

# %%
import numpy as np
from matplotlib.pylab import plt
# %matplotlib inline

# %%
# Plot all the close prices and convert it to cumulative
((df1.pct_change()+1).cumprod()).plot(figsize=(14, 10))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("OMV AG and Brent Crude returns between January 2016 and August 2020", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns', fontsize=14)
plt.xlabel('Months', fontsize=14)


# Plot the grid lines
plt.grid(which="major", color='grey', linestyle='-', linewidth=0.75)
plt.show()
